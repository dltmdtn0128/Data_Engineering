# %%
import pandas as pd
import csv
import xml.etree.ElementTree as ET

# %%
rows=[]
with open('catalog.csv',encoding ='utf-8') as f:
    reader=csv.reader(f)
    for row in reader:
        rows.append(row)
rows
# Out:
# [['Empire Burlesque', 'Bob Dylan', 'USA', 'Columbia', '10.90', '1985'],
#  ['Hide your heart', 'Bonnie Tyler', 'UK', 'CBS Records', '9.90', '1988'],
#  ['Greatest Hits', 'Dolly Parton', 'USA', 'RCA', '9.90', '1982'],
#  ['Still got the blues',
#   'Gary Moore',
#   'UK',
#   'Virgin records',
#   '10.20',
#   '1990'],
#  ['Eros', 'Eros Ramazzotti', 'EU', 'BMG', '9.90', '1997'],
#  ['One night only', 'Bee Gees', 'UK', 'Polydor', '10.90', '1998'],
#  ['Sylvias Mother', 'Dr.Hook', 'UK', 'CBS', '8.10', '1973'],
#  ['Maggie May', 'Rod Stewart', 'UK', 'Pickwick', '8.50', '1990'],
#  ['Romanza', 'Andrea Bocelli', 'EU', 'Polydor', '10.80', '1996'],
#  ['When a man loves a woman',
#   'Percy Sledge',
#   'USA',
#   'Atlantic',
#   '8.70',
#   '1987'],
#  ['Black angel', 'Savage Rose', 'EU', 'Mega', '10.90', '1995'],
#  ['1999 Grammy Nominees', 'Many', 'USA', 'Grammy', '10.20', '1999'],
#  ['For the good times', 'Kenny Rogers', 'UK', 'Mucik Master', '8.70', '1995'],
# ...

# %%
tree=ET.parse('catalog.xml')
root=tree.getroot()

# %%
catalog =[]
for cd in root.findall('CD'):
    title=cd.find('TITLE').text
    artist=cd.find('ARTIST').text
    country=cd.find('COUNTRY').text
    company=cd.find('COMPANY').text
    price=cd.find('PRICE').text
    year=cd.find('YEAR').text
    catalog.append([title,artist,country,company,price,year])

# %%
catalog
# Out:
# [['Empire Burlesque', 'Bob Dylan', 'USA', 'Columbia', '10.90', '1985'],
#  ['Hide your heart', 'Bonnie Tyler', 'UK', 'CBS Records', '9.90', '1988'],
#  ['Greatest Hits', 'Dolly Parton', 'USA', 'RCA', '9.90', '1982'],
#  ['Still got the blues',
#   'Gary Moore',
#   'UK',
#   'Virgin records',
#   '10.20',
#   '1990'],
#  ['Eros', 'Eros Ramazzotti', 'EU', 'BMG', '9.90', '1997'],
#  ['One night only', 'Bee Gees', 'UK', 'Polydor', '10.90', '1998'],
#  ['Sylvias Mother', 'Dr.Hook', 'UK', 'CBS', '8.10', '1973'],
#  ['Maggie May', 'Rod Stewart', 'UK', 'Pickwick', '8.50', '1990'],
#  ['Romanza', 'Andrea Bocelli', 'EU', 'Polydor', '10.80', '1996'],
#  ['When a man loves a woman',
#   'Percy Sledge',
#   'USA',
#   'Atlantic',
#   '8.70',
#   '1987'],
#  ['Black angel', 'Savage Rose', 'EU', 'Mega', '10.90', '1995'],
#  ['1999 Grammy Nominees', 'Many', 'USA', 'Grammy', '10.20', '1999'],
#  ['For the good times', 'Kenny Rogers', 'UK', 'Mucik Master', '8.70', '1995'],
# ...

# %%
for row in rows:
    if row[5] >='1991':
        print(row)
# Out:
# ['Eros', 'Eros Ramazzotti', 'EU', 'BMG', '9.90', '1997']
# ['One night only', 'Bee Gees', 'UK', 'Polydor', '10.90', '1998']
# ['Romanza', 'Andrea Bocelli', 'EU', 'Polydor', '10.80', '1996']
# ['Black angel', 'Savage Rose', 'EU', 'Mega', '10.90', '1995']
# ['1999 Grammy Nominees', 'Many', 'USA', 'Grammy', '10.20', '1999']
# ['For the good times', 'Kenny Rogers', 'UK', 'Mucik Master', '8.70', '1995']
# ['Big Willie style', 'Will Smith', 'USA', 'Columbia', '9.90', '1997']
# ['Soulsville', 'Jorn Hoel', 'Norway', 'WEA', '7.90', '1996']
# ['Pavarotti Gala Concert', 'Luciano Pavarotti', 'UK', 'DECCA', '9.90', '1991']

# %%
df=pd.DataFrame(catalog,columns=['Title','Atist','Country','Company','Price','Year'])

# %%
df
# Out:
#                        Title              Atist Country         Company  \
# 0           Empire Burlesque          Bob Dylan     USA        Columbia
# 1            Hide your heart       Bonnie Tyler      UK     CBS Records
# 2              Greatest Hits       Dolly Parton     USA             RCA
# 3        Still got the blues         Gary Moore      UK  Virgin records
# 4                       Eros    Eros Ramazzotti      EU             BMG
# 5             One night only           Bee Gees      UK         Polydor
# 6             Sylvias Mother            Dr.Hook      UK             CBS
# 7                 Maggie May        Rod Stewart      UK        Pickwick
# 8                    Romanza     Andrea Bocelli      EU         Polydor
# 9   When a man loves a woman       Percy Sledge     USA        Atlantic
# 10               Black angel        Savage Rose      EU            Mega
# 11      1999 Grammy Nominees               Many     USA          Grammy
# ...

# %%
df1= df[:20]
df1
# Out:
#                        Title            Atist Country         Company  Price  \
# 0           Empire Burlesque        Bob Dylan     USA        Columbia  10.90
# 1            Hide your heart     Bonnie Tyler      UK     CBS Records   9.90
# 2              Greatest Hits     Dolly Parton     USA             RCA   9.90
# 3        Still got the blues       Gary Moore      UK  Virgin records  10.20
# 4                       Eros  Eros Ramazzotti      EU             BMG   9.90
# 5             One night only         Bee Gees      UK         Polydor  10.90
# 6             Sylvias Mother          Dr.Hook      UK             CBS   8.10
# 7                 Maggie May      Rod Stewart      UK        Pickwick   8.50
# 8                    Romanza   Andrea Bocelli      EU         Polydor  10.80
# 9   When a man loves a woman     Percy Sledge     USA        Atlantic   8.70
# 10               Black angel      Savage Rose      EU            Mega  10.90
# ...

# %%
df2=df1.drop('Country',axis=1)
df2
# Out:
#                        Title            Atist         Company  Price  Year
# 0           Empire Burlesque        Bob Dylan        Columbia  10.90  1985
# 1            Hide your heart     Bonnie Tyler     CBS Records   9.90  1988
# 2              Greatest Hits     Dolly Parton             RCA   9.90  1982
# 3        Still got the blues       Gary Moore  Virgin records  10.20  1990
# 4                       Eros  Eros Ramazzotti             BMG   9.90  1997
# 5             One night only         Bee Gees         Polydor  10.90  1998
# 6             Sylvias Mother          Dr.Hook             CBS   8.10  1973
# 7                 Maggie May      Rod Stewart        Pickwick   8.50  1990
# 8                    Romanza   Andrea Bocelli         Polydor  10.80  1996
# 9   When a man loves a woman     Percy Sledge        Atlantic   8.70  1987
# 10               Black angel      Savage Rose            Mega  10.90  1995
# ...

# %%
df2.to_csv('seungsoolee.csv')

# %%
df2.iloc[4,0] ='2018113536'
df2.iloc[4,1] = '이승수'

# %%
df2
# Out:
#                        Title           Atist         Company  Price  Year
# 0           Empire Burlesque       Bob Dylan        Columbia  10.90  1985
# 1            Hide your heart    Bonnie Tyler     CBS Records   9.90  1988
# 2              Greatest Hits    Dolly Parton             RCA   9.90  1982
# 3        Still got the blues      Gary Moore  Virgin records  10.20  1990
# 4                 2018113536             이승수             BMG   9.90  1997
# 5             One night only        Bee Gees         Polydor  10.90  1998
# 6             Sylvias Mother         Dr.Hook             CBS   8.10  1973
# 7                 Maggie May     Rod Stewart        Pickwick   8.50  1990
# 8                    Romanza  Andrea Bocelli         Polydor  10.80  1996
# 9   When a man loves a woman    Percy Sledge        Atlantic   8.70  1987
# 10               Black angel     Savage Rose            Mega  10.90  1995
# 11      1999 Grammy Nominees            Many          Grammy  10.20  1999
# ...
